# %%
c1 = ["36", "00", "BE", "F7", "B0", "67", "6D", "04", "CA", "57", "EB", "32", "D5", "66", "AF", "EB", "22", 
      "86", "76", "B3", "60", "61", "B9", "8F", "5D", "E6", "9E", "3E", "D1", "CD", "03", "E5", "89", "D9", 
      "CE", "C6", "CD", "E4", "1D", "0F", "E1", "32", "44", "47", "39", "77", "1E", "78", "71", "F6", "2B", 
      "5A", "33", "E9", "14"]
c1_hex = []

for i in range(len(c1)):
    #print(bin(int(c1[i], 16)))
    c1_hex.append(bin(int(c1[i], 16)))
#print(len(c1_hex))

c1_binary = []
for hex_str in c1:
    binary_str = bin(int(hex_str, 16))[2:].zfill(8)
    c1_binary.append(binary_str)
print(c1_binary)

ascii_string = "".join([chr(int(c1_str, 16)) for c1_str in c1])
print(ascii_string)
# Out:
# ['00110110', '00000000', '10111110', '11110111', '10110000', '01100111', '01101101', '00000100', '11001010', '01010111', '11101011', '00110010', '11010101', '01100110', '10101111', '11101011', '00100010', '10000110', '01110110', '10110011', '01100000', '01100001', '10111001', '10001111', '01011101', '11100110', '10011110', '00111110', '11010001', '11001101', '00000011', '11100101', '10001001', '11011001', '11001110', '11000110', '11001101', '11100100', '00011101', '00001111', '11100001', '00110010', '01000100', '01000111', '00111001', '01110111', '00011110', '01111000', '01110001', '11110110', '00101011', '01011010', '00110011', '11101001', '00010100']
# 6¾÷°gmÊWë2Õf¯ë"v³`a¹]æ>ÑÍåÙÎÆÍäá2DG9wxqö+Z3é

# %%
c2 = ["23", "48", "AC", "B8", "AA", "6E", "68", "50", "9E", "56", "F9", "66", "9D", "7B", "AF", "E4", "2D", 
      "D4", "05", "B3", "7E", "67", "AF", "CF", "5D", "D0", "98", "3F", "83", "DC", "4B", "E0", "8E", "D8", 
      "D8", "C6", "C5", "E5", "58", "41", "E0", "29", "10", "12", "30", "73", "1E", "78", "72", "F8", "7C", 
      "6B", "37", "E0", "1A", "30", "A4", "6B", "8A", "4A", "4B", "8A", "DB", "E0", "B9", "0D", "73", "56", 
      "C2", "15", "F6"]

c2_hex = []

for i in range(len(c2)):
    #print(bin(int(c2[i], 16)))
    c2_hex.append(bin(int(c2[i], 16)))
#print(len(c2_hex))

c2_binary = []
for hex_str in c2:
    binary_str = bin(int(hex_str, 16))[2:].zfill(8)
    c2_binary.append(binary_str)
print(c2_binary)

ascii_string = "".join([chr(int(c2_str, 16)) for c2_str in c2])
print(ascii_string)
# Out:
# ['00100011', '01001000', '10101100', '10111000', '10101010', '01101110', '01101000', '01010000', '10011110', '01010110', '11111001', '01100110', '10011101', '01111011', '10101111', '11100100', '00101101', '11010100', '00000101', '10110011', '01111110', '01100111', '10101111', '11001111', '01011101', '11010000', '10011000', '00111111', '10000011', '11011100', '01001011', '11100000', '10001110', '11011000', '11011000', '11000110', '11000101', '11100101', '01011000', '01000001', '11100000', '00101001', '00010000', '00010010', '00110000', '01110011', '00011110', '01111000', '01110010', '11111000', '01111100', '01101011', '00110111', '11100000', '00011010', '00110000', '10100100', '01101011', '10001010', '01001010', '01001011', '10001010', '11011011', '11100000', '10111001', '00001101', '01110011', '01010110', '11000010', '00010101', '11110110']
# sVÂö

# %%
c3 = ["35", "00", "A2", "F7", "9F", "6D", "68", "4F", "CA", "69", "F0", "6B", "9A", "7C", "E7", "EB", "3F", 
      "86", "43", "B3", "6A", "63", "E9", "C1", "2A", "EF", "89", "7A", "82", "CC", "08", "E4", "C7", "DC", 
      "D8", "87", "D9", "E2", "01", "0F", "E6", "33", "10", "13", "36", "71", "04", "36", "66", "BA", "3D", 
      "5C", "3A", "BA"]

c3_hex = []

for i in range(len(c3)):
    #print(bin(int(c3[i], 16)))
    c3_hex.append(bin(int(c3[i], 16)))
#print(len(c3_hex))

c3_binary = []
for hex_str in c3:
    binary_str = bin(int(hex_str, 16))[2:].zfill(8)
    c3_binary.append(binary_str)
print(c3_binary)

ascii_string = "".join([chr(int(c3_str, 16)) for c3_str in c3])
print(ascii_string)
# Out:
# ['00110101', '00000000', '10100010', '11110111', '10011111', '01101101', '01101000', '01001111', '11001010', '01101001', '11110000', '01101011', '10011010', '01111100', '11100111', '11101011', '00111111', '10000110', '01000011', '10110011', '01101010', '01100011', '11101001', '11000001', '00101010', '11101111', '10001001', '01111010', '10000010', '11001100', '00001000', '11100100', '11000111', '11011100', '11011000', '10000111', '11011001', '11100010', '00000001', '00001111', '11100110', '00110011', '00010000', '00010011', '00110110', '01110001', '00000100', '00110110', '01100110', '10111010', '00111101', '01011100', '00111010', '10111010']
# äÇÜØÙâæ36q6fº=\:º

# %%
c4 = ["3B", "07", "AE", "F7", "B9", "70", "69", "50", "99", "4B", "F6", "7E", "D3", "6F", "E7", "F6", "6C", 
      "C7", "4B", "B6", "29", "4F", "F6", "8C", "12", "E8", "9E", "76", "D1", "D3", "04", "E5", "89", "DB", 
      "D9", "C6", "CE", "EF", "58", "5B", "E7", "38", "10", "00", "31", "7C", "04", "36", "79", "B0", "7C", 
      "59", "30", "F7", "4E", "28", "A5", "78"]

c4_hex = []

for i in range(len(c4)):
    #print(bin(int(c4[i], 16)))
    c4_hex.append(bin(int(c4[i], 16)))
#print(len(c4_hex))

c4_binary = []
for hex_str in c4:
    binary_str = bin(int(hex_str, 16))[2:].zfill(8)
    c4_binary.append(binary_str)
print(c4_binary)

ascii_string = "".join([chr(int(c4_str, 16)) for c4_str in c4])
print(ascii_string)
# Out:
# ['00111011', '00000111', '10101110', '11110111', '10111001', '01110000', '01101001', '01010000', '10011001', '01001011', '11110110', '01111110', '11010011', '01101111', '11100111', '11110110', '01101100', '11000111', '01001011', '10110110', '00101001', '01001111', '11110110', '10001100', '00010010', '11101000', '10011110', '01110110', '11010001', '11010011', '00000100', '11100101', '10001001', '11011011', '11011001', '11000110', '11001110', '11101111', '01011000', '01011011', '11100111', '00111000', '00010000', '00000000', '00110001', '01111100', '00000100', '00110110', '01111001', '10110000', '01111100', '01011001', '00110000', '11110111', '01001110', '00101000', '10100101', '01111000']
# ;®÷¹piPKö~ÓoçölÇK¶)OöèvÑÓåÛÙÆÎïX[ç81|6y°|Y0÷N(¥x

# %%
c5 = ["2B", "1C", "FC", "A4", "F8", "75", "64", "11", "9E", "1E", "F9", "7E", "D6", "28", "FB", "EA", "29", 
      "86", "42", "BB", "7B", "6A", "A5", "C1", "0E", "EE", "9E", "3D", "D1", "D8", "1F", "AC", "90", "DB", 
      "D9", "82", "C5", "F8", "1F", "5C", "A1", "7D", "64", "0F", "3B", "61", "57", "72", "7F", "B2", "32", 
      "18", "2B", "A5", "51", "33", "A4", "6A", "C3", "58", "03", "82", "C1", "E0", "B1", "18", "20", "5E", 
      "8B", "0F", "FD", "4A", "FD", "9F", "C2", "8D", "CF"]

c5_hex = []

for i in range(len(c5)):
    #print(bin(int(c5[i], 16)))
    c5_hex.append(bin(int(c5[i], 16)))
#print(len(c5_hex))

c5_binary = []
for hex_str in c5:
    binary_str = bin(int(hex_str, 16))[2:].zfill(8)
    c5_binary.append(binary_str)
print(c5_binary)

ascii_string = "".join([chr(int(c5_str, 16)) for c5_str in c5])
print(ascii_string)
# Out:
# ['00101011', '00011100', '11111100', '10100100', '11111000', '01110101', '01100100', '00010001', '10011110', '00011110', '11111001', '01111110', '11010110', '00101000', '11111011', '11101010', '00101001', '10000110', '01000010', '10111011', '01111011', '01101010', '10100101', '11000001', '00001110', '11101110', '10011110', '00111101', '11010001', '11011000', '00011111', '10101100', '10010000', '11011011', '11011001', '10000010', '11000101', '11111000', '00011111', '01011100', '10100001', '01111101', '01100100', '00001111', '00111011', '01100001', '01010111', '01110010', '01111111', '10110010', '00110010', '00011000', '00101011', '10100101', '01010001', '00110011', '10100100', '01101010', '11000011', '01011000', '00000011', '10000010', '11000001', '11100000', '10110001', '00011000', '00100000', '01011110', '10001011', '00001111', '11111101', '01001010', '11111101', '10011111', '11000010', '10001101', '11001111']
# +ü¤øudù~Ö(ûê)B»{j¥Áî=ÑØ¬ÛÙÅø\¡}d;aWr²2+¥Q3¤jÃXÁà± ^ýJýÂÏ

# %%
c6 = ["2D", "1D", "A9", "F7", "B4", "6B", "7A", "15", "99", "1E", "EF", "7B", "D6", "64", "AF", "E1", "24", 
      "C7", "4B", "B5", "6C", "26", "A1", "89", "18", "E9", "D0", "2E", "9E", "D4", "04", "FE", "95", "D1", 
      "CA", "C6", "CF", "F9", "15", "4A", "FC", "73", "10", "33", "31", "76", "1E", "71", "7E", "A2", "7C", 
      "50", "2A", "F7", "1A", "35", "AE", "7C", "91", "5B", "18", "C3", "D1", "B2", "BB", "03", "3D", "1B", 
      "DF", "13", "F7", "4A", "EA", "9F", "DF", "9E", "80", "47", "93", "C0", "6C", "46", "E4", "95", "81", 
      "84"]

c6_hex = []
for i in range(len(c6)):
    #print(bin(int(c6[i], 16)))
    c6_hex.append(bin(int(c6[i], 16)))
#print(len(c6_hex))

c6_binary = []
for hex_str in c6:
    binary_str = bin(int(hex_str, 16))[2:].zfill(8)
    c6_binary.append(binary_str)
print(c6_binary)

ascii_string = "".join([chr(int(c6_str, 16)) for c6_str in c6])
print(ascii_string)
# Out:
# ['00101101', '00011101', '10101001', '11110111', '10110100', '01101011', '01111010', '00010101', '10011001', '00011110', '11101111', '01111011', '11010110', '01100100', '10101111', '11100001', '00100100', '11000111', '01001011', '10110101', '01101100', '00100110', '10100001', '10001001', '00011000', '11101001', '11010000', '00101110', '10011110', '11010100', '00000100', '11111110', '10010101', '11010001', '11001010', '11000110', '11001111', '11111001', '00010101', '01001010', '11111100', '01110011', '00010000', '00110011', '00110001', '01110110', '00011110', '01110001', '01111110', '10100010', '01111100', '01010000', '00101010', '11110111', '00011010', '00110101', '10101110', '01111100', '10010001', '01011011', '00011000', '11000011', '11010001', '10110010', '10111011', '00000011', '00111101', '00011011', '11011111', '00010011', '11110111', '01001010', '11101010', '10011111', '11011111', '10011110', '10000000', '01000111', '10010011', '11000000', '01101100', '01000110', '11100100', '
# ...

# %%
c7 = ["23", "48", "A8", "B8", "B6", "65", "2C", "00", "86", "5F", "E1", "77", "DE", "28", "E0", "EC", "6C", 
      "C7", "05", "A1", "66", "6A", "B9", "C1", "0E", "E6", "88", "35", "81", "D1", "04", "E2", "82", "90", 
      "9D", "A7", "8C", "F5", "0A", "4E", "F5", "24", "10", "14", "31", "6D", "19", "72", "38", "F6", "1D", 
      "1F", "33", "EA", "54", "38", "A7", "64", "C3", "5C", "04", "96", "DB", "A4", "FA", "54", "12", "1B", 
      "C8", "09", "EB", "4A", "FA", "9E", "CD", "9E", "C1", "5D", "82", "8C", "64", "47", "B1", "8D", "81", 
      "8A", "94", "4C", "71", "BD", "6F", "8C", "A0", "CF", "F8", "06", "1A", "23", "93", "F7", "A4", "23", 
      "A9", "BF", "91"]

c7_hex = []
for i in range(len(c7)):
    #print(bin(int(c7[i], 16)))
    c7_hex.append(bin(int(c7[i], 16)))
#print(len(c7_hex))

c7_binary = []
for hex_str in c7:
    binary_str = bin(int(hex_str, 16))[2:].zfill(8)
    c7_binary.append(binary_str)
print(c7_binary)

ascii_string = "".join([chr(int(c7_str, 16)) for c7_str in c7])
print(ascii_string)
# Out:
# ['00100011', '01001000', '10101000', '10111000', '10110110', '01100101', '00101100', '00000000', '10000110', '01011111', '11100001', '01110111', '11011110', '00101000', '11100000', '11101100', '01101100', '11000111', '00000101', '10100001', '01100110', '01101010', '10111001', '11000001', '00001110', '11100110', '10001000', '00110101', '10000001', '11010001', '00000100', '11100010', '10000010', '10010000', '10011101', '10100111', '10001100', '11110101', '00001010', '01001110', '11110101', '00100100', '00010000', '00010100', '00110001', '01101101', '00011001', '01110010', '00111000', '11110110', '00011101', '00011111', '00110011', '11101010', '01010100', '00111000', '10100111', '01100100', '11000011', '01011100', '00000100', '10010110', '11011011', '10100100', '11111010', '01010100', '00010010', '00011011', '11001000', '00001001', '11101011', '01001010', '11111010', '10011110', '11001101', '10011110', '11000001', '01011101', '10000010', '10001100', '01100100', '01000111', '10110001', '
# ...

# %%
c8 = ["31", "07", "FB", "A4", "AC", "63", "75", "50", "9D", "57", "EC", "7A", "9A", "65", "EA", "A2", "2D", 
      "C8", "41", "F2", "61", "69", "BA", "85", "5D", "EA", "95", "7A", "85", "D0", "0C", "E4", "93", "9E", 
      "DC", "88", "C8", "B6", "1C", "4E", "E1", "3E", "55", "47", "32", "71", "1C", "73", "36", "BF", "28", 
      "4C", "7F", "F1", "52", "38", "EB", "71", "82", "5C", "1F", "C3", "DB", "A9", "B3", "1C", "27", "1B", 
      "C4", "1D", "B2", "1E", "E6", "93", "8C", "9D", "8E", "5B", "8B", "84", "26"]

c8_hex = []
for i in range(len(c8)):
    #print(bin(int(c8[i], 16)))
    c8_hex.append(bin(int(c8[i], 16)))
#print(len(c8_hex))

c8_binary = []
for hex_str in c8:
    binary_str = bin(int(hex_str, 16))[2:].zfill(8)
    c8_binary.append(binary_str)
print(c8_binary)

ascii_string = "".join([chr(int(c8_str, 16)) for c8_str in c8])
print(ascii_string)
# Out:
# ['00110001', '00000111', '11111011', '10100100', '10101100', '01100011', '01110101', '01010000', '10011101', '01010111', '11101100', '01111010', '10011010', '01100101', '11101010', '10100010', '00101101', '11001000', '01000001', '11110010', '01100001', '01101001', '10111010', '10000101', '01011101', '11101010', '10010101', '01111010', '10000101', '11010000', '00001100', '11100100', '10010011', '10011110', '11011100', '10001000', '11001000', '10110110', '00011100', '01001110', '11100001', '00111110', '01010101', '01000111', '00110010', '01110001', '00011100', '01110011', '00110110', '10111111', '00101000', '01001100', '01111111', '11110001', '01010010', '00111000', '11101011', '01110001', '10000010', '01011100', '00011111', '11000011', '11011011', '10101001', '10110011', '00011100', '00100111', '00011011', '11000100', '00011101', '10110010', '00011110', '11100110', '10010011', '10001100', '10011101', '10001110', '01011011', '10001011', '10000100', '00100110']
# ...

# %%
c9 = ["3B", "0D", "A8", "FB", "F8", "71", "78", "19", "86", "52", "B4", "32", "F3", "28", "FC", "F6", "25", 
      "CA", "49", "F2", "6B", "63", "BA", "88", "18", "F1", "95", "74", "D1", "F0", "4B", "E7", "89", "D1", 
      "CA", "C6", "CD", "E5", "58", "43", "E0", "33", "57", "47", "3F", "6B", "57", "5F", "36", "B5", "3D", 
      "51", "7F", "EE", "5F", "38", "BB", "3D", "81", "4A", "07", "8A", "D0", "B6", "BD", "1A", "34", "17", 
      "8B", "32", "B5", "06", "E2", "D6", "C0", "83", "97", "4C", "C9"]

c9_hex = []
for i in range(len(c9)):
    #print(bin(int(c9[i], 16)))
    c9_hex.append(bin(int(c9[i], 16)))
#print(len(c9_hex))

c9_binary = []
for hex_str in c9:
    binary_str = bin(int(hex_str, 16))[2:].zfill(8)
    c9_binary.append(binary_str)
print(c9_binary)

ascii_string = "".join([chr(int(c9_str, 16)) for c9_str in c9])
print(ascii_string)
# Out:
# ['00111011', '00001101', '10101000', '11111011', '11111000', '01110001', '01111000', '00011001', '10000110', '01010010', '10110100', '00110010', '11110011', '00101000', '11111100', '11110110', '00100101', '11001010', '01001001', '11110010', '01101011', '01100011', '10111010', '10001000', '00011000', '11110001', '10010101', '01110100', '11010001', '11110000', '01001011', '11100111', '10001001', '11010001', '11001010', '11000110', '11001101', '11100101', '01011000', '01000011', '11100000', '00110011', '01010111', '01000111', '00111111', '01101011', '01010111', '01011111', '00110110', '10110101', '00111101', '01010001', '01111111', '11101110', '01011111', '00111000', '10111011', '00111101', '10000001', '01001010', '00000111', '10001010', '11010000', '10110110', '10111101', '00011010', '00110100', '00010111', '10001011', '00110010', '10110101', '00000110', '11100010', '11010110', '11000000', '10000011', '10010111', '01001100', '11001001']
# ...

# %%
c10 = ["31", "09", "B2", "B0", "B7", "6C", "2C", "07", "8B", "4D", "B8", "71", "C8", "69", "F5", "E7", "28", 
       "8A", "05", "B0", "7C", "72", "F6", "92", "15", "E2", "D0", "2D", "90", "CA", "4B", "FE", "82", "DF", 
       "D1", "C6", "CD", "F8", "1C", "0F", "E9", "32", "42", "47", "31", "76", "12", "36", "7B", "B9", "31", 
       "5A", "31", "F1", "16", "7D", "82", "3D", "80", "40", "1E", "8F", "D1", "E0", "B2", "11", "36", "57"]

c10_hex = []
for i in range(len(c10)):
    #print(bin(int(c10[i], 16)))
    c10_hex.append(bin(int(c10[i], 16)))
#print(len(c10_hex))

c10_binary = []
for hex_str in c10:
    binary_str = bin(int(hex_str, 16))[2:].zfill(8)
    c10_binary.append(binary_str)
print(c10_binary)

ascii_string = "".join([chr(int(c10_str, 16)) for c10_str in c10])
print(ascii_string)
# Out:
# ['00110001', '00001001', '10110010', '10110000', '10110111', '01101100', '00101100', '00000111', '10001011', '01001101', '10111000', '01110001', '11001000', '01101001', '11110101', '11100111', '00101000', '10001010', '00000101', '10110000', '01111100', '01110010', '11110110', '10010010', '00010101', '11100010', '11010000', '00101101', '10010000', '11001010', '01001011', '11111110', '10000010', '11011111', '11010001', '11000110', '11001101', '11111000', '00011100', '00001111', '11101001', '00110010', '01000010', '01000111', '00110001', '01110110', '00010010', '00110110', '01111011', '10111001', '00110001', '01011010', '00110001', '11110001', '00010110', '01111101', '10000010', '00111101', '10000000', '01000000', '00011110', '10001111', '11010001', '11100000', '10110010', '00010001', '00110110', '01010111']
# 1	²°·l,M¸qÈiõç(°|röâÐ-ÊKþßÑÆÍøé2BG1v6{¹1Z1ñ}=@Ñà²6W

# %%
6¾÷°gmÊWë2Õf¯ë"v³`a¹]æ>ÑÍåÙÎÆÍäá2DG9wxqö+Z3é
sVÂönhPVùf{¯ä-Ô³~g¯Ï]Ð?ÜKàØØÆÅåXAà)0sxrø|k7à0¤kJKÛà¹
5¢÷mhOÊiðk|çë?C³jcéÁ*ïzäÇÜØÙâæ36q6fº=\:º
;®÷¹piPKö~ÓoçölÇK¶)OöèvÑÓåÛÙÆÎïX[ç81|6y°|Y0÷N(¥x
+ü¤øudù~Ö(ûê)B»{j¥Áî=ÑØ¬ÛÙÅø\¡}d;aWr²2+¥Q3¤jÃXÁà± ^ýJýÂÏ

# %%
c10 = ["31", "09", "B2", "B0", "B7", "6C", "2C", "07", "8B", "4D", "B8", "71", "C8", "69", "F5", "E7", "28", 
       "8A", "05", "B0", "7C", "72", "F6", "92", "15", "E2", "D0", "2D", "90", "CA", "4B", "FE", "82", "DF", 
       "D1", "C6", "CD", "F8", "1C", "0F", "E9", "32", "42", "47", "31", "76", "12", "36", "7B", "B9", "31", 
       "5A", "31", "F1", "16", "7D", "82", "3D", "80", "40", "1E", "8F", "D1", "E0", "B2", "11", "36", "57"]

c10_binary = []

for hex_str in c10:
    binary_str = bin(int(hex_str, 16))[2:].zfill(8)
    c10_binary.append(binary_str)

print(c10_binary)
# Out:
# ['00110001', '00001001', '10110010', '10110000', '10110111', '01101100', '00101100', '00000111', '10001011', '01001101', '10111000', '01110001', '11001000', '01101001', '11110101', '11100111', '00101000', '10001010', '00000101', '10110000', '01111100', '01110010', '11110110', '10010010', '00010101', '11100010', '11010000', '00101101', '10010000', '11001010', '01001011', '11111110', '10000010', '11011111', '11010001', '11000110', '11001101', '11111000', '00011100', '00001111', '11101001', '00110010', '01000010', '01000111', '00110001', '01110110', '00010010', '00110110', '01111011', '10111001', '00110001', '01011010', '00110001', '11110001', '00010110', '01111101', '10000010', '00111101', '10000000', '01000000', '00011110', '10001111', '11010001', '11100000', '10110010', '00010001', '00110110', '01010111']

# %%
1. 
36 00 BE F7 B0 67 6D 04 CA 57 EB 32 D5 66 AF EB 22 86 76 B3 60 61 B9 8F 5D E6 9E 3E D1 CD 03 E5 89 D9 CE C6 CD E4 1D 0F E1 32 44 47 39 77 1E 78 71 F6 2B 5A 33 E9 14
00110110 00000000 10111110 11110111 10110000 01100111 01101101 00000100 11001010 01010111 11101011 00110010 11010101 01100110 10101111 11101011 00100010 10000110 01110110 10110011 01100000 01100001 10111001 10001111 01011101 11100110 10011110 00111110 11010001 11001101 00000011 11100101 10001001 11011001 11001110 11000110 11001101 11100100 00011101 00001111 11100001 00110010 01000100 01000111 00111001 01110111 00011110 01111000 01110001 11110110 00101011 01011010 00110011 11101001 00010100

2.
23 48 AC B8 AA 6E 68 50 9E 56 F9 66 9D 7B AF E4 2D D4 05 B3 7E 67 AF CF 5D D0 98 3F 83 DC 4B E0 8E D8 D8 C6 C5 E5 58 41 E0 29 10 12 30 73 1E 78 72 F8 7C 6B 37 E0 1A 30 A4 6B 8A 4A 4B 8A DB E0 B9 0D 73 56 C2 15 F6
00100011 01001000 10101100 10111000 10101010 01101110 01101000 01010000 10011110 01010110 11111001 01100110 10011101 01111011 10101111 11100100 00101101 11010100 00000101 10110011 01111110 01100111 10101111 11001111 01011101 11010000 10011000 00111111 10000011 11011100 01001011 11100000 10001110 11011000 11011000 11000110 11000101 11100101 01011000 01000001 11100000 00101001 00010000 00010010 00110000 01110011 00011110 01111000 01110010 11111000 01111100 01101011 00110111 11100000 00011010 00110000 10100100 01101011 10001010 01001010 01001011 10001010 11011011 11100000 10111001 00001101 01110011 01010110 11000010 00010101 11110110

3. 
35 00 A2 F7 9F 6D 68 4F CA 69 F0 6B 9A 7C E7 EB 3F 86 43 B3 6A 63 E9 C1 2A EF 89 7A 82 CC 08 E4 C7 DC D8 87 D9 E2 01 0F E6 33 10 13 36 71 04 36 66 BA 3D 5C 3A BA

4. 
3B 07 AE F7 B9 70 69 50 99 4B F6 7E D3 6F E7 F6 6C C7 4B B6 29 4F F6 8C 12 E8 9E 76 D1 D3 04 E5 89 DB D9 C6 CE EF 58 5B E7 38 10 00 31 7C 04 36 79 B0 7C 59 30 F7 4E 28 A5 78

5. 
2B 1C FC A4 F8 75 64 11 9E 1E F9 7E D6 28 FB EA 29 86 42 BB 7B 6A A5 C1 0E EE 9E 3D D1 D8 1F AC 90 DB D9 82 C5 F8 1F 5C A1 7D 64 0F 3B 61 57 72 7F B2 32 18 2B A5 51 33 A4 6A C3 58 03 82 C1 E0 B1 18 20 5E 8B 0F FD 4A FD 9F C2 8D CF

6. 
2D 1D A9 F7 B4 6B 7A 15 99 1E EF 7B D6 64 AF E1 24 C7 4B B5 6C 26 A1 89 18 E9 D0 2E 9E D4 04 FE 95 D1 CA C6 CF F9 15 4A FC 73 10 33 31 76 1E 71 7E A2 7C 50 2A F7 1A 35 AE 7C 91 5B 18 C3 D1 B2 BB 03 3D 1B DF 13 F7 4A EA 9F DF 9E 80 47 93 C0 6C 46 E4 95 81 84

7. 
23 48 A8 B8 B6 65 2C 00 86 5F E1 77 DE 28 E0 EC 6C C7 05 A1 66 6A B9 C1 0E E6 88 35 81 D1 04 E2 82 90 9D A7 8C F5 0A 4E F5 24 10 14 31 6D 19 72 38 F6 1D 1F 33 EA 54 38 A7 64 C3 5C 04 96 DB A4 FA 54 12 1B C8 09 EB 4A FA 9E CD 9E C1 5D 82 8C 64 47 B1 8D 81 8A 94 4C 71 BD 6F 8C A0 CF F8 06 1A 23 93 F7 A4 23 A9 BF 91

8. 
31 07 FB A4 AC 63 75 50 9D 57 EC 7A 9A 65 EA A2 2D C8 41 F2 61 69 BA 85 5D EA 95 7A 85 D0 0C E4 93 9E DC 88 C8 B6 1C 4E E1 3E 55 47 32 71 1C 73 36 BF 28 4C 7F F1 52 38 EB 71 82 5C 1F C3 DB A9 B3 1C 27 1B C4 1D B2 1E E6 93 8C 9D 8E 5B 8B 84 26

9. 
3B 0D A8 FB F8 71 78 19 86 52 B4 32 F3 28 FC F6 25 CA 49 F2 6B 63 BA 88 18 F1 95 74 D1 F0 4B E7 89 D1 CA C6 CD E5 58 43 E0 33 57 47 3F 6B 57 5F 36 B5 3D 51 7F EE 5F 38 BB 3D 81 4A 07 8A D0 B6 BD 1A 34 17 8B 32 B5 06 E2 D6 C0 83 97 4C C9

10. 
31 09 B2 B0 B7 6C 2C 07 8B 4D B8 71 C8 69 F5 E7 28 8A 05 B0 7C 72 F6 92 15 E2 D0 2D 90 CA 4B FE 82 DF D1 C6 CD F8 1C 0F E9 32 42 47 31 76 12 36 7B B9 31 5A 31 F1 16 7D 82 3D 80 40 1E 8F D1 E0 B2 11 36 57
